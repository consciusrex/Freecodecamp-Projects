# %%
import numpy as np
import pandas as pd
import matplotlib as mat

#D:\learning\DA\freecodecamp\demographic data analyser

# %%
data=pd.read_csv("D:/learning/DA/freecodecamp/demographic data analyser/adultdata.csv")

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#race counts
data["race"].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
data[["age", 'sex']]
# Out:
#        age     sex
# 0       39    Male
# 1       50    Male
# 2       38    Male
# 3       53    Male
# 4       28  Female
# ...    ...     ...
# 32556   27  Female
# 32557   40    Male
# 32558   58  Female
# 32559   22    Male
# 32560   52  Female
#
# [32561 rows x 2 columns]

# %%
a=data[['sex', 'age']]

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
a=data.loc[data['sex']=="Male",['sex','age']].groupby('sex').mean()
a
# Out:
#             age
# sex
# Male  39.433547

# %%
bachelors=data.loc[data['education']=='Bachelors',['education']]
count_of_bachelors=bachelors.value_counts()

total_count=len(data.index) #data.shape[0] gives number of row counts || data.index
type(count_of_bachelors)
# Out:
# pandas.core.series.Series

# %%
percent = ((count_of_bachelors/total_count)*100).round(2)
print(percent)
# Out:
# education
# Bachelors    16.45
# dtype: float64

# %%
advanced_edu=data.loc[((data['education'] == 'Bachelors')| (data['education'] =='Masters')| (data['education'] =='Doctorate'))]
count=len(advanced_edu.index)

advanced_edu_50K=filtered.loc[filtered['salary']=='>50K']
final_count=len(advanced_edu_50K.index)

percent = round(((final_count/count)*100),2)
print('people with advanced degree earning greater than 50K', percent)
# Out:
# people with advanced degree earning greater than 50K 46.54

# %%
basic_degree=data.loc[(data['education'] != 'Bachelors') & (data['education'] !='Masters')& (data['education'] !='Doctorate')]


basic_degree_50K=basic_degree.loc[~((data['education'] == 'Bachelors') | (data['education'] =='Masters') | (data['education'] =='Doctorate')) 
                              & (basic_degree['salary']=='>50K')]


percent = round(((len(basic_degree_50K.index)/len(basic_degree.index))*100),2)

print('people with basic degree earning greater than 50K', percent)
# Out:
# people with basic degree earning greater than 50K 17.37

# %%
#What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

salary50K = data.loc[(data['hours-per-week'] == data['hours-per-week'].min()) & (data['salary'] =='>50K')]
minimum_hours_week_count = data.loc[(data['hours-per-week'] == data['hours-per-week'].min())]
percent=(len(salary50K.index)/len(minimum_hours_week_count)*100)
print('People who work for minimum number of hours a week and earn more than 50K is', percent)
# Out:
# People who work for minimum number of hours a week and earn more than 50K is 10.0

# %%
#What country has the highest percentage of people that earn >50K and what is that percentage?

country_50K = data[data['salary']=='>50K']
high_income_countries = country_50K['native-country'].value_counts()
country_with_50K= data.loc[(data["native-country"]==high_income_countries.idxmax()) & (data['salary']=='>50K')]
with_50K= data.loc[(data['salary']=='>50K')]
percentage_of_people_that_earn_50K=round((len(country_with_50K)/len(with_50K)*100),2)
print(high_income_countries.idxmax(),"has the highest percentage of people that earn >50K is", percentage_of_people_that_earn_50K)
# Out:
# United-States has the highest percentage of people that earn >50K is 91.46

# %%
salary_50K=data[data['salary']=='>50K']
occupation=salary_50K['occupation'].value_counts()
occupation.idxmax()
# Out:
# 'Exec-managerial'

# %%
country_50K = data[data['salary']=='>50K']
India_high_income_count = country_50K[country_50K['native-country']=='India']['occupation'].value_counts()

India_high_income_count.idxmax()
# Out:
# 'Prof-specialty'

# %%
country_with_50K= data.loc[(data["native-country"]==high_income_countries.idxmax()) & (data['salary']=='>50K')]
country_with_50K
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 19      43  Self-emp-not-inc  292175       Masters             14
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 7      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...
